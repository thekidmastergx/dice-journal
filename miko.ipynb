# %%
import dice

# %%
dice.demo()

# %%
dice.plotD(3,6)

# %%
dice.plotD(3,6,mod=2)

# %%
dice.plotD(3,6,drop=2)

# %%
dice.plotD(3,6,mod=2,drop=2)

# %%
dice.plotD(4,6,drop=2)

# %%
dice.plotD(2,6,mod=-4)

# %%
dice.plotD(3,6,mod=-30)

# %%
dice.plotD(2,100,mod=-50,drop=1)
